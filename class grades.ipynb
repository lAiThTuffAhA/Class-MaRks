# %% [markdown]
# <a href="https://colab.research.google.com/github/lAiThTuffAhA/apple-basket/blob/main/class%20grades.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openpyxl import load_workbook
import pandas as pd
book=load_workbook('8Astudents.xlsx')
sheet=book.active
from xlrd import open_workbook

LA1=[]
LA2=[]
LA3=[]
for item1 in range (0,10):
  X=input('enter the Arabic marks for all students in class A ')
  LA1.append(X)
for item2 in range (0,10):
  Y=input('enter the Math marks for all students in class A ')
  LA2.append(Y)
for item3 in range (0,10):
  Z=input('enter the English marks for all students in class A ')
  LA3.append(Z)

q=(int(LA1[0])+int(LA2[0])+int(LA3[0]))/3
r=(int(LA1[1])+int(LA2[1])+int(LA3[1]))/3
c=(int(LA1[2])+int(LA2[2])+int(LA3[2]))/3
m=(int(LA1[3])+int(LA2[3])+int(LA3[3]))/3
n=(int(LA1[4])+int(LA2[4])+int(LA3[4]))/3
v=(int(LA1[5])+int(LA2[5])+int(LA3[5]))/3
e=(int(LA1[6])+int(LA2[6])+int(LA3[6]))/3
t=(int(LA1[7])+int(LA2[7])+int(LA3[7]))/3
p=(int(LA1[8])+int(LA2[8])+int(LA3[8]))/3
s=(int(LA1[9])+int(LA2[9])+int(LA3[9]))/3
LA4=[q,r,c,m,n,v,e,t,p,s]
maxvalue=max(LA4)

sheet['i5']=maxvalue

sheet['b2']=int(LA1[0])
sheet['b3']=int(LA1[1])
sheet['b4']=int(LA1[2])
sheet['b5']=int(LA1[3])
sheet['b6']=int(LA1[4])
sheet['b7']=int(LA1[5])
sheet['b8']=int(LA1[6])
sheet['b9']=int(LA1[7])
sheet['b10']=int(LA1[8])
sheet['b11']=int(LA1[9])

sheet['c2']=int(LA2[0])
sheet['c3']=int(LA2[1])
sheet['c4']=int(LA2[2])
sheet['c5']=int(LA2[3])
sheet['c6']=int(LA2[4])
sheet['c7']=int(LA2[5])
sheet['c8']=int(LA2[6])
sheet['c9']=int(LA2[7])
sheet['c10']=int(LA2[8])
sheet['c11']=int(LA2[9])

sheet['d2']=int(LA3[0])
sheet['d3']=int(LA3[1])
sheet['d4']=int(LA3[2])
sheet['d5']=int(LA3[3])
sheet['d6']=int(LA3[4])
sheet['d7']=int(LA3[5])
sheet['d8']=int(LA3[6])
sheet['d9']=int(LA3[7])
sheet['d10']=int(LA3[8])
sheet['d11']=int(LA3[9])

sheet['e2']=int(LA4[0])
sheet['e3']=int(LA4[1])
sheet['e4']=int(LA4[2])
sheet['e5']=int(LA4[3])
sheet['e6']=int(LA4[4])
sheet['e7']=int(LA4[5])
sheet['e8']=int(LA4[6])
sheet['e9']=int(LA4[7])
sheet['e10']=int(LA4[8])
sheet['e11']=int(LA4[9])

dictionary={
    'Ahmad':LA4[0],
    'Ali':LA4[1],
    'Arwa':LA4[2],
    'Sara':LA4[3],
    'Mohammad':LA4[4],
    'Ghada':LA4[5],
    'Juman':LA4[6],
    'Samer':LA4[7],
    'Abdulla':LA4[8],
    'Lama':LA4[9]

}

maximum = max(dictionary, key=dictionary.get)  
c=maximum, dictionary[maximum]
sheet['h5']=c[0]

book.save(" classgradesA.xlsx")
print('please check the classgradesA file ')
# Out:
# enter the Arabic marks for all students in class A 67
# enter the Arabic marks for all students in class A 87
# enter the Arabic marks for all students in class A 98
# enter the Arabic marks for all students in class A 80
# enter the Arabic marks for all students in class A 75
# enter the Arabic marks for all students in class A 72
# enter the Arabic marks for all students in class A 97
# enter the Arabic marks for all students in class A 56
# enter the Arabic marks for all students in class A 87
# enter the Arabic marks for all students in class A 75
# enter the Math marks for all students in class A 67
# enter the Math marks for all students in class A 64
# enter the Math marks for all students in class A 69
# enter the Math marks for all students in class A 63
# enter the Math marks for all students in class A 60
# enter the Math marks for all students in class A 73
# enter the Math marks for all students in class A 81
# enter the Math marks for all students in class A 80
# ...
